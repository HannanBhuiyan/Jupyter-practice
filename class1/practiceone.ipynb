# %%
print("hello world")
# Out:
# hello world

# %%
name = "hannna"
print(name)
# Out:
# hannna

# %%
name = "jhon"

# %%
print(name)
# Out:
# jhon

# %%
x = 20

# %%
y = 30

# %%
z = x + y

# %%
print(z)
# Out:
# 50

# %%
print("sdfasdf")
# Out:
# sdfasdf
